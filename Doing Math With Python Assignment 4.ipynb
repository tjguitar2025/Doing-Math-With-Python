# %%
from pylab import plot, show, title, xlabel, ylabel, legend
atl_temp = [53, 53, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52 ]
atl_time = ["4:00", "5:00", "6:00", "7:00", "8:00", "9:00", "10:00", "11:00", "12:00", "1:00", "2:00", "3:00"]
plot(atl_time, atl_temp, marker='o')
title('Temperature in Atlanta from 4pm February 17 to 3am February 18')
xlabel('Hours')
ylabel('Temperature')
# Out:
# Text(0, 0.5, 'Temperature')

# %%
'''
Quadratic function calculator
'''

# Assume values of x
x_values = range(-10,10, 1)
y_values = []
for x in x_values:
    # Calculate the value of the quadratic function
    y_values.append(x**2 + 2*x +1)
    
plot(x_values, y_values, marker = "o")
